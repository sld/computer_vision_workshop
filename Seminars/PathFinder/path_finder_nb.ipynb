# %%
from headers import *
from path_finder import PathFinder

PathFinder('./data/Klad00.jpg').find_and_draw()

# %%
PathFinder('./data/Klad01.jpg').find_and_draw()

# %%
PathFinder('./data/Klad02.jpg').find_and_draw()
